# %%
# %%bash
# date
# Out:
# Wed Jul 19 13:34:30 PDT 2017

# %%
# %%bash
# system_profiler SPSoftwareDataType
# Out:
# Software:
#
#     System Software Overview:
#
#       System Version: OS X 10.9.5 (13F34)
#       Kernel Version: Darwin 13.4.0
#       Boot Volume: Hummingbird
#       Boot Mode: Normal
#       Computer Name: hummingbird
#       User Name: srlab (srlab)
#       Secure Virtual Memory: Enabled
#       Time since boot: 43 minutes

# %% [markdown]
# This is all happening in scaphapoda on Eagle

# %% [markdown]
# Blast practice *C. gigas* with Swiss Prot

# %% [markdown]
# Source: https://github.com/sr320/nb-2017/blob/master/C_gigas/data/Cg_Gigaton_proteins.fa

# %% [markdown]
# Finding location of BLAST database

# %%
# %%bash
# ls -l /Volumes/
# Out:
# total 8
# drwxrwxr-x  21 root   admin   782 Nov  9  2016 Data
# lrwxr-xr-x   1 root   admin     1 Jul 19 12:54 Hummingbird -> /
# drwxr-xr-x@ 30 root   wheel  1088 Jan  8  2014 Mirror
# drwxrwxr-x  15 srlab  staff   578 Sep 16  2016 toaster
# drwx------@  1 srlab  staff   500 Oct  9  2015 web

# %%
# %%bash
# ls -l /Volumes/Data/
# Out:
# total 0
# drwxr-xr-x     9 srlab   admin    306 Jan 28  2014 CLC_local_bird
# drwxr-xr-x     3 srlab   admin    102 Oct 17  2016 Hollie
# drwxr-xr-x     6 root    admin    204 Jan 28  2015 Lisa
# drwxr-xr-x     7 Sam     admin    238 Apr  7  2015 Sam
# drwxr-xr-x     9 srlab   admin    306 Nov  9  2016 Sean
# drwxr-xr-x@   48 srlab   admin   1632 Nov 22  2016 Ubuntu 64-bit 16.04.1.vmwarevm
# drwxrwxrwx  1255 srlab   admin  42670 Sep 16  2016 blast_db
# drwxr-xr-x    86 root    admin   2924 Jul  3  2014 galaxy-dist
# drwxr-xr-x    10 gilesg  admin    340 Aug 11  2014 giles
# drwxrwxrwx     3 srlab   admin    102 Sep 14  2016 sr320_scratch

# %%
# %%bash
# ls /Volumes/Data/blast_db/
# Out:
# Crassostrea_gigas.GCA_000297895.1.24.fa.nhr
# Crassostrea_gigas.GCA_000297895.1.24.fa.nin
# Crassostrea_gigas.GCA_000297895.1.24.fa.nog
# Crassostrea_gigas.GCA_000297895.1.24.fa.nsd
# Crassostrea_gigas.GCA_000297895.1.24.fa.nsi
# Crassostrea_gigas.GCA_000297895.1.24.fa.nsq
# Strongylocentrotus_purpuratus.GCA_000002235.2.22.pep.all.fa
# Strongylocentrotus_purpuratus.GCA_000002235.2.22.pep.all.phr
# Strongylocentrotus_purpuratus.GCA_000002235.2.22.pep.all.pin
# Strongylocentrotus_purpuratus.GCA_000002235.2.22.pep.all.psq
# cdd_delta.aux
# cdd_delta.loo
# cdd_delta.obsr
# cdd_delta.phr
# cdd_delta.pin
# cdd_delta.psd
# cdd_delta.psi
# cdd_delta.psq
# cdd_delta.rps
# cdd_delta.wcounts
# env_nr.00.phd
# env_nr.00.phi
# env_nr.00.phr
# env_nr.00.pin
# env_nr.00.pnd
# env_nr.00.pni
# env_nr.00.pog
# env_nr.00.ppd
# env_nr.00.ppi
# env_nr.00.psd
# env_nr.00.psi
# env_nr.00.psq
# env_nr.01.phd
# env_nr.01.phi
# env_nr.01.phr
# env_nr.01.pin
# env_nr.01.pnd
# env_nr.01.pni
# env_nr.01.pog
# ...

# %%
# %%bash
# pwd
# Out:
# /Users/srlab/gitrepos/LabDocs/jupyter_nbs/grace

# %%
# %%bash
# blastx \
# -query /Volumes/web/Grace/Transcriptomes/c_gigas/query.fa \
# -db /Volumes/Data/blast_db/uniprot_sprot \
# -max_target_seqs 1 \
# -max_hsps 1 \
# -outfmt 6 \
# -num_threads 8 \
# -out /Volumes/web/Grace/Transcriptomes/c_gigas/blast_gigas_sprot.tab
