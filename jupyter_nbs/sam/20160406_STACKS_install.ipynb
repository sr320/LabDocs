# %%
# !date
# Out:
# Wed Apr  6 11:53:38 PDT 2016

# %%
# %%bash
# system_profiler SPSoftwareDataType
# Out:
# Software:
#
#     System Software Overview:
#
#       System Version: OS X 10.9.5 (13F34)
#       Kernel Version: Darwin 13.4.0
#       Boot Volume: Hummingbird
#       Boot Mode: Normal
#       Computer Name: hummingbird
#       User Name: Sam (Sam)
#       Secure Virtual Memory: Enabled
#       Time since boot: 137 days 20:44

# %%
# %%bash
# wget http://catchenlab.life.illinois.edu/stacks/source/stacks-1.37.tar.gz
# Out:
# --2016-04-06 11:55:33--  http://catchenlab.life.illinois.edu/stacks/source/stacks-1.37.tar.gz
# Resolving catchenlab.life.illinois.edu... 130.126.48.94
# Connecting to catchenlab.life.illinois.edu|130.126.48.94|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 504569 (493K) [application/x-gzip]
# Saving to: 'stacks-1.37.tar.gz'
#
#      0K .......... .......... .......... .......... .......... 10%  508K 1s
#     50K .......... .......... .......... .......... .......... 20% 1018K 1s
#    100K .......... .......... .......... .......... .......... 30% 28.5M 0s
#    150K .......... .......... .......... .......... .......... 40% 43.0M 0s
#    200K .......... .......... .......... .......... .......... 50% 1.01M 0s
#    250K .......... .......... .......... .......... .......... 60% 18.9M 0s
#    300K .......... .......... .......... .......... .......... 71% 1.06M 0s
#    350K .......... .......... .......... .......... .......... 81% 4.78M 0s
# ...

# %%
cp stacks-1.37.tar.gz /usr/local/bioinformatics/
# Out:
# cp: /usr/local/bioinformatics/stacks-1.37.tar.gz: Permission denied

# %%
ls /usr/local/bioinformatics/stacks*
# Out:
# /usr/local/bioinformatics/stacks@             /usr/local/bioinformatics/stacks-1.37.tar.gz
#
# /usr/local/bioinformatics/stacks-1.13:
# bin/   share/

# %%
tar -zxvf /usr/local/bioinformatics/stacks-1.37.tar.gz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4e01bb15e112> in <module>()
# ----> 1 tar -zxvf /usr/local/bioinformatics/stacks-1.37.tar.gz
#
# NameError: name 'tar' is not defined

# %%
# %%bash
# tar -zxvf /usr/local/bioinformatics/stacks-1.37.tar.gz
# Out:
# x stacks-1.37/
# x stacks-1.37/acinclude.m4
# x stacks-1.37/aclocal.m4
# x stacks-1.37/autogen.sh
# x stacks-1.37/ChangeLog
# x stacks-1.37/config/
# x stacks-1.37/config.h.in
# x stacks-1.37/configure
# x stacks-1.37/configure.ac
# x stacks-1.37/INSTALL
# x stacks-1.37/LICENSE
# x stacks-1.37/Makefile.am
# x stacks-1.37/Makefile.in
# x stacks-1.37/php/
# x stacks-1.37/README
# x stacks-1.37/scripts/
# x stacks-1.37/sql/
# x stacks-1.37/src/
# x stacks-1.37/tests/
# x stacks-1.37/tests/kmer_filter.t
# x stacks-1.37/tests/process_radtags.t
# x stacks-1.37/tests/pstacks.t
# x stacks-1.37/tests/ustacks.t
# x stacks-1.37/src/BamI.h
# x stacks-1.37/src/BamUnalignedI.h
# x stacks-1.37/src/bootstrap.h
# x stacks-1.37/src/BowtieI.h
# x stacks-1.37/src/BustardI.h
# x stacks-1.37/src/catalog_utils.cc
# x stacks-1.37/src/catalog_utils.h
# x stacks-1.37/src/clean.cc
# x stacks-1.37/src/clean.h
# x stacks-1.37/src/clone_filter.cc
# x stacks-1.37/src/clone_filter.h
# x stacks-1.37/src/cmb.cc
# ...

# %%
# %%bash
# wget https://github.com/sparsehash/sparsehash/archive/master.zip
# Out:
# --2016-04-06 12:09:13--  https://github.com/sparsehash/sparsehash/archive/master.zip
# Resolving github.com... 192.30.252.120
# Connecting to github.com|192.30.252.120|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/sparsehash/sparsehash/zip/master [following]
# --2016-04-06 12:09:13--  https://codeload.github.com/sparsehash/sparsehash/zip/master
# Resolving codeload.github.com... 192.30.252.161
# Connecting to codeload.github.com|192.30.252.161|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: 'master.zip'
#
#      0K .......... .......... .......... .......... ..........  327K
#     50K .......... .......... .......... .......... ..........  655K
#    100K .......... .......... .......... .......... .......... 26.1M
#    150K .......... .......... .......... .......... .......... 26.7M
# ...

# %%
# %%bash
# unzip master.zip
# Out:
# Archive:  master.zip
# 4a36398d442cc86f47d2d7e751596cc2430ad135
#    creating: sparsehash-master/
#   inflating: sparsehash-master/.gitignore
#   inflating: sparsehash-master/AUTHORS
#   inflating: sparsehash-master/COPYING
#   inflating: sparsehash-master/ChangeLog
#   inflating: sparsehash-master/INSTALL
#   inflating: sparsehash-master/Makefile.am
#   inflating: sparsehash-master/Makefile.in
#   inflating: sparsehash-master/NEWS
#   inflating: sparsehash-master/README
#   inflating: sparsehash-master/README_windows.txt
#   inflating: sparsehash-master/TODO
#   inflating: sparsehash-master/aclocal.m4
#   inflating: sparsehash-master/autogen.sh
#   inflating: sparsehash-master/config.guess
#   inflating: sparsehash-master/config.sub
#   inflating: sparsehash-master/configure
#   inflating: sparsehash-master/configure.ac
#   inflating: sparsehash-master/depcomp
#    creating: sparsehash-master/doc/
#   inflating: sparsehash-master/doc/dense_hash_map.html
# ...

# %%
cd sparsehash-master/
# Out:
# /Users/Sam/sparsehash-master

# %%
# %%bash
# ./configure
# Out:
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... ./install-sh -c -d
# checking for gawk... no
# checking for mawk... no
# checking for nawk... no
# checking for awk... awk
# checking whether make sets $(MAKE)... yes
# checking for g++... g++
# checking whether the C++ compiler works... yes
# checking for C++ compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking for style of include used by make... GNU
# checking dependency style of g++... gcc3
# checking for gcc... gcc
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# ...

# %%
# %%bash
# make
# Out:
# [ -d src/sparsehash/internal ] || mkdir -p src/sparsehash/internal
# echo "/*" > src/sparsehash/internal/_sparsehash_config
# echo " * NOTE: This file is for internal use only." >> src/sparsehash/internal/_sparsehash_config
# echo " *       Do not use these #defines in your own program!" >> src/sparsehash/internal/_sparsehash_config
# echo " */" >> src/sparsehash/internal/_sparsehash_config
# awk '{prevline=currline; currline=$0;} \
# 	        /^#/ {in_second_file = 1;} \
# 	        !in_second_file {if (currline !~ /^ *$/) {inc[currline]=0}}; \
# 	       	in_second_file { for (i in inc) { \
# 	       	                   if (index(currline, i) != 0) { \
# 	       	                      print "\n"prevline"\n"currline; \
# 	       	                      delete inc[i]; \
# 	       	                   } \
# 	       	                 } }' \
# 	./src/config.h.include ./src/config.h \
# 	>> src/sparsehash/internal/_sparsehash_config
# ...

# %%
# %%bash
# make install
# Out:
# /Applications/Xcode.app/Contents/Developer/usr/bin/make  install-am
# test -z "/usr/local/lib" || ./install-sh -c -d "/usr/local/lib"
# test -z "/usr/local/share/doc/sparsehash-2.0.2" || ./install-sh -c -d "/usr/local/share/doc/sparsehash-2.0.2"
#  /usr/bin/install -c -m 644 AUTHORS COPYING ChangeLog INSTALL NEWS README README_windows.txt TODO doc/dense_hash_map.html doc/dense_hash_set.html doc/sparse_hash_map.html doc/sparse_hash_set.html doc/sparsetable.html doc/implementation.html doc/performance.html doc/index.html doc/designstyle.css '/usr/local/share/doc/sparsehash-2.0.2'
# test -z "/usr/local/include/google" || ./install-sh -c -d "/usr/local/include/google"
#  /usr/bin/install -c -m 644 src/google/dense_hash_map src/google/dense_hash_set src/google/sparse_hash_map src/google/sparse_hash_set src/google/sparsetable src/google/template_util.h src/google/type_traits.h '/usr/local/include/google'
# ...

# %%
cd /usr/local/bioinformatics/
# Out:
# /usr/local/bioinformatics

# %%
# %%bash
# tar -zxvf stacks-1.37.tar.gz
# Out:
# x stacks-1.37/: Can't create 'stacks-1.37'
# x stacks-1.37/acinclude.m4: Failed to create dir 'stacks-1.37'Can't create 'stacks-1.37/acinclude.m4'
# x stacks-1.37/aclocal.m4: Failed to create dir 'stacks-1.37'Can't create 'stacks-1.37/aclocal.m4'
# x stacks-1.37/autogen.sh: Failed to create dir 'stacks-1.37'Can't create 'stacks-1.37/autogen.sh'
# x stacks-1.37/ChangeLog: Failed to create dir 'stacks-1.37'Can't create 'stacks-1.37/ChangeLog'
# x stacks-1.37/config/: Failed to create dir 'stacks-1.37'Can't create 'stacks-1.37/config'
# x stacks-1.37/config.h.in: Failed to create dir 'stacks-1.37'Can't create 'stacks-1.37/config.h.in'
# x stacks-1.37/configure: Failed to create dir 'stacks-1.37'Can't create 'stacks-1.37/configure'
# x stacks-1.37/configure.ac: Failed to create dir 'stacks-1.37'Can't create 'stacks-1.37/configure.ac'
# x stacks-1.37/INSTALL: Failed to create dir 'stacks-1.37'Can't create 'stacks-1.37/INSTALL'
# ...

# %%
ls stack*
# Out:
# stacks@             stacks-1.37.tar.gz
#
# stacks-1.13:
# bin/   share/
#
# stacks-1.37:
# ChangeLog     LICENSE       Makefile.in   acinclude.m4  autogen.sh*   config.h.in   configure.ac  scripts/      src/
# INSTALL       Makefile.am   README        aclocal.m4    config/       configure*    php/          sql/          tests/

# %%
# %%bash
# wget https://sourceforge.net/projects/samtools/files/samtools/0.1.19/samtools-0.1.19.tar.bz2
# Out:
# --2016-04-06 12:19:29--  https://sourceforge.net/projects/samtools/files/samtools/0.1.19/samtools-0.1.19.tar.bz2
# Resolving sourceforge.net... 216.34.181.60
# Connecting to sourceforge.net|216.34.181.60|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://sourceforge.net/projects/samtools/files/samtools/0.1.19/samtools-0.1.19.tar.bz2/download [following]
# --2016-04-06 12:19:29--  https://sourceforge.net/projects/samtools/files/samtools/0.1.19/samtools-0.1.19.tar.bz2/download
# Connecting to sourceforge.net|216.34.181.60|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: http://downloads.sourceforge.net/project/samtools/samtools/0.1.19/samtools-0.1.19.tar.bz2?r=&ts=1459970470&use_mirror=iweb [following]
# --2016-04-06 12:19:30--  http://downloads.sourceforge.net/project/samtools/samtools/0.1.19/samtools-0.1.19.tar.bz2?r=&ts=1459970470&use_mirror=iweb
# Resolving downloads.sourceforge.net... 216.34.181.59
# ...

# %%
ls /Users/Sam/samtools-0.1.19.tar.bz2
# Out:
# /Users/Sam/samtools-0.1.19.tar.bz2

# %%
# %%bash
# bunzip2 /Users/Sam/samtools-0.1.19.tar.bz2

# %%
ls /Users/Sam/samtools-0.1.19*
# Out:
# /Users/Sam/samtools-0.1.19.tar

# %%
# %%bash
# tar -xjf /Users/Sam/samtools-0.1.19.tar
# Out:
# samtools-0.1.19/: Can't create 'samtools-0.1.19'
# samtools-0.1.19/.gitignore: Failed to create dir 'samtools-0.1.19'Can't create 'samtools-0.1.19/.gitignore'
# samtools-0.1.19/AUTHORS: Failed to create dir 'samtools-0.1.19'Can't create 'samtools-0.1.19/AUTHORS'
# samtools-0.1.19/COPYING: Failed to create dir 'samtools-0.1.19'Can't create 'samtools-0.1.19/COPYING'
# samtools-0.1.19/ChangeLog.old: Failed to create dir 'samtools-0.1.19'Can't create 'samtools-0.1.19/ChangeLog.old'
# samtools-0.1.19/INSTALL: Failed to create dir 'samtools-0.1.19'Can't create 'samtools-0.1.19/INSTALL'
# samtools-0.1.19/Makefile: Failed to create dir 'samtools-0.1.19'Can't create 'samtools-0.1.19/Makefile'
# samtools-0.1.19/Makefile.mingw: Failed to create dir 'samtools-0.1.19'Can't create 'samtools-0.1.19/Makefile.mingw'
# samtools-0.1.19/NEWS: Failed to create dir 'samtools-0.1.19'Can't create 'samtools-0.1.19/NEWS'
# ...

# %%
ls
# Out:
# FastQC/                     bismark_v0.14.2/            fastx_toolkit@              ngsplot@                    stacks@
# Trimmomatic@                bowtie@                     fastx_toolkit-0.0.13.2/     ngsplot-2.08/               stacks-1.13/
# Trimmomatic-0.30/           bowtie-1.0.0/               hmmer@                      rsem@                       stacks-1.37/
# Trinotate@                  bowtie2@                    hmmer-3.1b1/                rsem-1.2.10/                stacks-1.37.tar.gz
# Trinotate_r20140708/        bowtie2-2.1.0/              libgtextutils-0.6.1/        samtools-0.1.19/            tophat-2.0.13.OSX_x86_64/
# anaconda/                   cufflinks-2.2.1.OSX_x86_64/ ncbi-blast@                 signalp-4.1/                trinity@
# bedtools-2.22.1/            dbs/                        ncbi-blast-2.2.29+/         source.sh                   trinityrnaseq_r20131110/

# %%
cd samtools-0.1.19/
# Out:
# [Errno 13] Permission denied: 'samtools-0.1.19/'
# /usr/local/bioinformatics

# %%
cd samtools-0.1.19/
# Out:
# /usr/local/bioinformatics/samtools-0.1.19

# %%
# %%bash
# ./configure
# Out:
# bash: line 1: ./configure: No such file or directory

# %%
ls
# Out:
# AUTHORS             bam2bcf.h           bam_md.c            bam_tview_html.c    errmod.h            kprobaln.h          sam.c
# COPYING             bam2bcf_indel.c     bam_pileup.c        bamshuf.c           examples/           kseq.h              sam.h
# ChangeLog.old       bam2depth.c         bam_plcmd.c         bamtk.c             faidx.c             ksort.h             sam_header.c
# INSTALL             bam_aux.c           bam_reheader.c      bcftools/           faidx.h             kstring.c           sam_header.h
# Makefile            bam_cat.c           bam_rmdup.c         bedcov.c            kaln.c              kstring.h           sam_view.c
# Makefile.mingw      bam_color.c         bam_rmdupse.c       bedidx.c            kaln.h              misc/               sample.c
# NEWS                bam_endian.h        bam_sort.c          bgzf.c              khash.h             padding.c           sample.h
# ...

# %%
# %%bash
# make
# Out:
# gcc -c -g -Wall -O2 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE64_SOURCE -D_USE_KNETFILE -D_CURSES_LIB=1 -DBGZF_CACHE -I. bgzf.c -o bgzf.o
# gcc -c -g -Wall -O2 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE64_SOURCE -D_USE_KNETFILE -D_CURSES_LIB=1 -I. kstring.c -o kstring.o
# gcc -c -g -Wall -O2 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE64_SOURCE -D_USE_KNETFILE -D_CURSES_LIB=1 -I. bam_aux.c -o bam_aux.o
# gcc -c -g -Wall -O2 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE64_SOURCE -D_USE_KNETFILE -D_CURSES_LIB=1 -I. bam.c -o bam.o
# gcc -c -g -Wall -O2 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE64_SOURCE -D_USE_KNETFILE -D_CURSES_LIB=1 -I. bam_import.c -o bam_import.o
# gcc -c -g -Wall -O2 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE64_SOURCE -D_USE_KNETFILE -D_CURSES_LIB=1 -I. sam.c -o sam.o
# gcc -c -g -Wall -O2 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE64_SOURCE -D_USE_KNETFILE -D_CURSES_LIB=1 -I. bam_index.c -o bam_index.o
# ...

# %%
cd ../stacks-1.37/
# Out:
# /usr/local/bioinformatics/stacks-1.37

# %%
# %%bash
# ./configure --disable-openmp --enable-sparsehash --enable-bam
# Out:
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... config/install-sh -c -d
# checking for gawk... no
# checking for mawk... no
# checking for nawk... no
# checking for awk... awk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking for g++... g++
# checking whether the C++ compiler works... yes
# checking for C++ compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking for style of include used by make... GNU
# checking dependency style of g++... gcc3
# checking for gcc... gcc
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# ...

# %%
# %%bash
# make
# Out:
# /Applications/Xcode.app/Contents/Developer/usr/bin/make  all-am
# /bin/sh: src/.dirstamp: Permission denied
# make[1]: *** [src/.dirstamp] Error 1
# make: *** [all] Error 2

# %% [markdown]
# ./configure --with-bam-include-path=/usr/local/bionformatics/samtools-0.1.19
