# %% [markdown]
# ### System Info

# %%
# %%bash
# date
# Out:
# Tue Aug 16 09:47:04 PDT 2016

# %%
# %%bash
# hostname
# Out:
# robertsmac.fish.washington.edu

# %%
# %%bash
# system_profiler SPSoftwareDataType
# Out:
# Software:
#
#     System Software Overview:
#
#       System Version: Mac OS X 10.7.5 (11G63)
#       Kernel Version: Darwin 11.4.2
#       Boot Volume: SSD2
#       Boot Mode: Normal
#       Computer Name: greenbird (2)
#       User Name: Sam (Sam)
#       Secure Virtual Memory: Enabled
#       64-bit Kernel and Extensions: No
#       Time since boot: 6 days 17:56

# %%
# %%bash
# #Uses grep to exclude lines that display serial number and hardware UUID
# system_profiler SPHardwareDataType | grep -v [SH][ea]
# Out:
#       Model Name: Mac Pro
#       Model Identifier: MacPro1,1
#       Processor Name: Dual-Core Intel Xeon
#       Processor Speed: 3 GHz
#       Number of Processors: 2
#       Total Number of Cores: 4
#       L2 Cache (per Processor): 4 MB
#       Memory: 14 GB
#       Bus Speed: 1.33 GHz
#       Boot ROM Version: MP11.005C.B08
#       SMC Version (system): 1.7f10

# %% [markdown]
# ### Population Structure Analysis
#
# Am trying out [fastStructure](http://rajanil.github.io/fastStructure/). We'll see how it goes...
#
# [Raj et al. 2014](http://www.genetics.org/content/197/2/573)

# %%
cd
# Out:
# /Users/Sam

# %%
# %%bash
# mkdir 20160816_oly_gbs_fastStructure_analysis

# %%
cd 20160816_oly_gbs_fastStructure_analysis/
# Out:
# /Users/Sam/20160816_oly_gbs_fastStructure_analysis

# %% [markdown]
# ### Install fastStructure

# %%
# %%bash
# git clone https://github.com/rajanil/fastStructure
# Out:
# Cloning into fastStructure...

# %%
ls
# Out:
# fastStructure/

# %% [markdown]
# ####  Check system to see if Cython, numpy, and scipy dependencies are already installed

# %%
# %%bash
# pip list | grep '[Cc]ython\|numpy\|scipy'
# Out:
# Cython (0.23.4)
# numpy (1.10.1)
# scipy (0.16.0)

# %% [markdown]
# #### Download GNU Scientific Library using Homebrew (don't think it's installed on this system and I don't know how to check)

# %%
# %%bash
# brew install gsl
# Out:
# ...
# Please install Xcode 4.5.1.
# ...
# Software installed with other package managers causes known problems for
# Homebrew. If a formula fails to build, uninstall MacPorts/Fink and try again.
# ==> Downloading http://ftpmirror.gnu.org/gsl/gsl-1.15.tar.gz
# ==> ./configure --prefix=/usr/local/Cellar/gsl/1.15
# ==> make
# ==> make install
# ...
# Homebrew does not append "/usr/local/share/aclocal"
# to "/usr/share/aclocal/dirlist". If an autoconf script you use
# requires these m4 macros, you'll need to add this path manually.
# ...
# Error: The `brew link` step did not complete successfully
# The formula built, but is not symlinked into /usr/local
# You can try again using `brew link gsl'
# ==> Summary
# /usr/local/Cellar/gsl/1.15: 237 files, 7.0M, built in 97 seconds

# %% [markdown]
# #### Download and unpack GNU Scientific Library

# %%
# %%bash
# cd
# wget http://open-source-box.org/gsl/gsl-latest.tar.gz
# tar -xzf gsl-latest.tar.gz
# Out:
# --2016-08-16 11:09:16--  http://open-source-box.org/gsl/gsl-latest.tar.gz
# Resolving open-source-box.org... 173.234.185.173
# Connecting to open-source-box.org|173.234.185.173|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3827265 (3.6M) [application/x-gzip]
# Saving to: `gsl-latest.tar.gz'
#
#      0K .......... .......... .......... .......... ..........  1%  304K 12s
#     50K .......... .......... .......... .......... ..........  2% 1.03M 8s
#    100K .......... .......... .......... .......... ..........  4%  996K 6s
#    150K .......... .......... .......... .......... ..........  5%  482K 6s
#    200K .......... .......... .......... .......... ..........  6% 25.9M 5s
#    250K .......... .......... .......... .......... ..........  8% 1.44M 5s
#    300K .......... .......... .......... .......... ..........  9% 1.74M 4s
#    350K .......... .......... .......... .......... .......... 10% 1.73M 4s
# ...

# %%
ls /Users/Sam/gsl-2.1/
# Out:
# AUTHORS                autogen.sh*            config.sub*            fit/                   gsl_mode.h             linalg/                multiset/              siman/                 test-driver*
# BUGS                   blas/                  configure*             gsl/                   gsl_nan.h              ltmain.sh              ntuple/                sort/                  test_gsl_histogram.sh*
# COPYING                block/                 configure.ac           gsl-config.in*         gsl_pow_int.h          matrix/                ode-initval/           spblas/                utils/
# ChangeLog              bspline/               const/                 gsl-histogram.c        gsl_precision.h        mdate-sh               ode-initval2/          specfunc/              vector/
# INSTALL                build.h                depcomp*               gsl-randist.c          gsl_types.h            min/                   permutation/           splinalg/              version.c
# ...

# %%
# %%bash
# cat /Users/Sam/gsl-2.1/INSTALL
# Out:
# Installation Instructions
# *************************
#
# Copyright (C) 1994-1996, 1999-2002, 2004-2013 Free Software Foundation,
# Inc.
#
#    Copying and distribution of this file, with or without modification,
# are permitted in any medium without royalty provided the copyright
# notice and this notice are preserved.  This file is offered as-is,
# without warranty of any kind.
#
# Basic Installation
# ...
#
#    Briefly, the shell commands `./configure; make; make install' should
# configure, build, and install this package.  The following
# more-detailed instructions are generic; see the `README' file for
# instructions specific to this package.  Some packages provide this
# `INSTALL' file but do not implement all of the features documented
# below.  The lack of an optional feature in a given package is not
# necessarily a bug.  More recommendations for GNU packages can be found
# in *note Makefile Conventions: (standards)Makefile Conventions.
#
# ...

# %% [markdown]
# #### Install GSL

# %%
cd /Users/Sam/gsl-2.1/
# Out:
# /Users/Sam/gsl-2.1

# %%
# %%bash
# ./configure
# Out:
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... ./install-sh -c -d
# checking for gawk... no
# checking for mawk... no
# checking for nawk... no
# checking for awk... awk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking whether to enable maintainer-specific portions of Makefiles... no
# checking for a sed that does not truncate output... /usr/bin/sed
# checking whether make sets $(MAKE)... (cached) yes
# checking build system type... x86_64-apple-darwin11.4.2
# checking host system type... x86_64-apple-darwin11.4.2
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# ...

# %%
# %%bash
# make
# Out:
# make  all-recursive
# Making all in gsl
# rm -f gsl*.h
# HEADERLIST="../gsl*.h ../*/gsl*.h"; \
# 	for h in $HEADERLIST; do \
# 	  BASENAME=`basename $h`; \
# 	  test -r $BASENAME || ln -s $h $BASENAME; \
# 	done
# Making all in utils
# /bin/sh ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..     -g -O2 -MT placeholder.lo -MD -MP -MF .deps/placeholder.Tpo -c -o placeholder.lo placeholder.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -g -O2 -MT placeholder.lo -MD -MP -MF .deps/placeholder.Tpo -c placeholder.c  -fno-common -DPIC -o .libs/placeholder.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -g -O2 -MT placeholder.lo -MD -MP -MF .deps/placeholder.Tpo -c placeholder.c -o placeholder.o >/dev/null 2>&1
# mv -f .deps/placeholder.Tpo .deps/placeholder.Plo
# /bin/sh ../libtool  --tag=CC   --mode=link gcc  -g -O2   -o libutils.la  placeholder.lo  -lm
# libtool: link: ar cru .libs/libutils.a .libs/placeholder.o
# libtool: link: ranlib .libs/libutils.a
# ...

# %%
# %%bash
# time make install
# Out:
# Making install in gsl
# make[2]: Nothing to be done for `install-exec-am'.
# make[2]: Nothing to be done for `install-data-am'.
# Making install in utils
# make[2]: Nothing to be done for `install-exec-am'.
# make[2]: Nothing to be done for `install-data-am'.
# Making install in sys
# make[2]: Nothing to be done for `install-exec-am'.
#  .././install-sh -c -d '/usr/local/include/gsl'
#  /usr/bin/install -c -m 644 gsl_sys.h '/usr/local/include/gsl'
# Making install in test
# make[2]: Nothing to be done for `install-exec-am'.
#  .././install-sh -c -d '/usr/local/include/gsl'
#  /usr/bin/install -c -m 644 gsl_test.h '/usr/local/include/gsl'
# Making install in err
# make[2]: Nothing to be done for `install-exec-am'.
#  .././install-sh -c -d '/usr/local/include/gsl'
#  /usr/bin/install -c -m 644 gsl_errno.h gsl_message.h '/usr/local/include/gsl'
# Making install in const
# make[2]: Nothing to be done for `install-exec-am'.
#  .././install-sh -c -d '/usr/local/include/gsl'
# ...

# %% [markdown]
# ##### Ran the above command with ```sudo``` outside of notebook

# %% [markdown]
# #### Build Python extensions

# %% [markdown]
# ##### Add the GSL libraries to ```.bash_profile``` so they are included in system variables

# %%
# %%bash
# echo -e "\n#Add GSL to PATH for fastStructure" >> /Users/Sam/.bash_profile
# echo "export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/usr/local/lib" >> /Users/Sam/.bash_profile
# echo 'export CFLAGS="-I/usr/local/include"' >> /Users/Sam/.bash_profile
# echo 'export LDFLAGS="-L/usr/local/lib"' >> /Users/Sam/.bash_profile
# cat /Users/Sam/.bash_profile
# Out:
# export PATH="$PATH:/usr/local/bin/FastQC"
#
# # added by Anaconda2 2.4.1 installer
# export PATH="/Users/Sam/Applications/anaconda/bin:$PATH"
# export LD_LIBRARY_PATH=:/usr/local/lib
# export CFLAGS="-I/usr/local/include"
# export LDFLAGS="-L/usr/local/lib"
#
# #Add GSL to PATH for fastStructure
# export LD_LIBRARY_PATH=:/usr/local/lib
# export CFLAGS="-I/usr/local/include"
# export LDFLAGS="-L/usr/local/lib"

# %%
# %%bash
# source /Users/Sam/.bash_profile

# %% [markdown]
# ##### Build the library extensions

# %%
cd /Users/Sam/20160816_oly_gbs_fastStructure_analysis/fastStructure/vars/
# Out:
# /Users/Sam/20160816_oly_gbs_fastStructure_analysis/fastStructure/vars

# %%
# %%bash
# python setup.py build_ext --inplace
# Out:
# running build_ext
# cythoning utils.pyx to utils.c
# building 'utils' extension
# creating build
# creating build/temp.macosx-10.5-x86_64-2.7
# /usr/bin/clang -fno-strict-aliasing -I/Users/Sam/Applications/anaconda/include -arch x86_64 -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Sam/Applications/anaconda/lib/python2.7/site-packages/numpy/core/include -I. -I/Users/Sam/Applications/anaconda/include/python2.7 -c utils.c -o build/temp.macosx-10.5-x86_64-2.7/utils.o
# /usr/bin/clang -bundle -undefined dynamic_lookup -L/Users/Sam/Applications/anaconda/lib -arch x86_64 -arch x86_64 build/temp.macosx-10.5-x86_64-2.7/utils.o -L/Users/Sam/Applications/anaconda/lib -o /Users/Sam/20160816_oly_gbs_fastStructure_analysis/fastStructure/vars/utils.so
# Compiling admixprop.pyx because it changed.
# Compiling allelefreq.pyx because it changed.
# Compiling marglikehood.pyx because it changed.
# [1/3] Cythonizing admixprop.pyx
# [2/3] Cythonizing allelefreq.pyx
# ...

# %% [markdown]
# These warnings might be OK...

# %% [markdown]
# #### Compile Cython scripts

# %%
cd /Users/Sam/20160816_oly_gbs_fastStructure_analysis/fastStructure/
# Out:
# /Users/Sam/20160816_oly_gbs_fastStructure_analysis/fastStructure

# %%
# %%bash
# python setup.py build_ext --inplace
# Out:
# running build_ext
# cythoning parse_bed.pyx to parse_bed.c
# building 'parse_bed' extension
# creating build
# creating build/temp.macosx-10.5-x86_64-2.7
# /usr/bin/clang -fno-strict-aliasing -I/Users/Sam/Applications/anaconda/include -arch x86_64 -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Sam/Applications/anaconda/lib/python2.7/site-packages/numpy/core/include -I. -I/Users/Sam/Applications/anaconda/include/python2.7 -c parse_bed.c -o build/temp.macosx-10.5-x86_64-2.7/parse_bed.o
# /usr/bin/clang -bundle -undefined dynamic_lookup -L/Users/Sam/Applications/anaconda/lib -arch x86_64 -arch x86_64 build/temp.macosx-10.5-x86_64-2.7/parse_bed.o -L/Users/Sam/Applications/anaconda/lib -o /Users/Sam/20160816_oly_gbs_fastStructure_analysis/fastStructure/parse_bed.so
# running build_ext
# cythoning parse_str.pyx to parse_str.c
# building 'parse_str' extension
# ...

# %% [markdown]
# These warnings might be OK...

# %% [markdown]
# ### Run fastStructure

# %% [markdown]
# #### Use Structure output file from PyRAD analysis
#
# #### Specify three populations (```-K 3```)

# %%
# %%bash
# time python structure.py -K 3 \
# --input=/Users/Sam/20160715_pyrad_outfiles/oly_gbs_pyrad.str \
# --output=/Users/Sam/20160816_oly_gbs_fastStructure_analysis/genotypes_output
# Out:
# Traceback (most recent call last):
#   File "structure.py", line 170, in <module>
#     G = parse_bed.load(params['inputfile'])
#   File "parse_bed.pyx", line 18, in parse_bed.load (parse_bed.c:1638)
#     handle = open(file+'.fam','r')
# IOError: [Errno 2] No such file or directory: '/Users/Sam/20160715_pyrad_outfiles/oly_gbs_pyrad.str.fam'
#
# real	0m1.641s
# user	0m0.296s
# sys	0m0.347s
